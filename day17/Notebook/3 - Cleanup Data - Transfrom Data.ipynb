# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
working_file = os.path.join(CACHE_DIR, 'movies-box-office-dataset.csv')
output_file = os.path.join(CACHE_DIR, 'movies-box-office-dataset-cleaned.csv')

# %%
df = pd.read_csv(working_file)

# %%
df.head(n=1200)
# Out:
#       Rank                                 Release Group       Worldwide  \
# 0        1                                   Toy Story 3  $1,066,969,703
# 1        2                           Alice in Wonderland  $1,025,467,110
# 2        3  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3        4                                     Inception    $828,322,032
# 4        5                           Shrek Forever After    $752,600,867
# ...    ...                                           ...             ...
# 1195    14                                Wreck-It Ralph    $471,222,889
# 1196    15                                Les Misérables    $441,809,770
# 1197    16                              Django Unchained    $425,368,238
# 1198    17                                    Prometheus    $403,354,469
# 1199    18                   Snow White and the Huntsman    $396,592,829
#
#           Domestic      %       Foreign    %.1  filename  year
# 0     $415,004,880  38.9%  $651,964,823  61.1%  2010.csv  2010
# 1     $334,191,110  32.6%  $691,276,000  67.4%  2010.csv  2010
# 2     $295,983,305  30.3%  $680,553,613  69.7%  2010.csv  2010
# 3     $292,576,195  35.3%  $535,745,837  64.7%  2010.csv  2010
# 4     $238,736,787  31.7%  $513,864,080  68.3%  2010.csv  2010
# ...            ...    ...           ...    ...       ...   ...
# 1195  $189,422,889  40.2%  $281,800,000  59.8%  2012.csv  2012
# 1196  $148,809,770  33.7%  $293,000,000  66.3%  2012.csv  2012
# 1197  $162,805,434  38.3%  $262,562,804  61.7%  2012.csv  2012
# 1198  $126,477,084  31.4%  $276,877,385  68.6%  2012.csv  2012
# 1199  $155,332,381  39.2%  $241,260,448  60.8%  2012.csv  2012
#
# [1200 rows x 9 columns]

# %%
df['Rank'] = -1

# %%
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0    -1                                   Toy Story 3  $1,066,969,703
# 1    -1                           Alice in Wonderland  $1,025,467,110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3    -1                                     Inception    $828,322,032
# 4    -1                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $415,004,880  38.9%  $651,964,823  61.1%  2010.csv  2010
# 1  $334,191,110  32.6%  $691,276,000  67.4%  2010.csv  2010
# 2  $295,983,305  30.3%  $680,553,613  69.7%  2010.csv  2010
# 3  $292,576,195  35.3%  $535,745,837  64.7%  2010.csv  2010
# 4  $238,736,787  31.7%  $513,864,080  68.3%  2010.csv  2010

# %%
df['Domestic %'] = df['%']
df['Foreign %'] = df["%.1"]

# %%
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0    -1                                   Toy Story 3  $1,066,969,703
# 1    -1                           Alice in Wonderland  $1,025,467,110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3    -1                                     Inception    $828,322,032
# 4    -1                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1  filename  year Domestic %  \
# 0  $415,004,880  38.9%  $651,964,823  61.1%  2010.csv  2010      38.9%
# 1  $334,191,110  32.6%  $691,276,000  67.4%  2010.csv  2010      32.6%
# 2  $295,983,305  30.3%  $680,553,613  69.7%  2010.csv  2010      30.3%
# 3  $292,576,195  35.3%  $535,745,837  64.7%  2010.csv  2010      35.3%
# 4  $238,736,787  31.7%  $513,864,080  68.3%  2010.csv  2010      31.7%
#
#   Foreign %
# 0     61.1%
# 1     67.4%
# 2     69.7%
# 3     64.7%
# 4     68.3%

# %%
# df.drop(['%', '%.1'], axis=1)
df.drop(columns=['%', '%.1'], inplace=True)
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0    -1                                   Toy Story 3  $1,066,969,703
# 1    -1                           Alice in Wonderland  $1,025,467,110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3    -1                                     Inception    $828,322,032
# 4    -1                           Shrek Forever After    $752,600,867
#
#        Domestic       Foreign  filename  year Domestic % Foreign %
# 0  $415,004,880  $651,964,823  2010.csv  2010      38.9%     61.1%
# 1  $334,191,110  $691,276,000  2010.csv  2010      32.6%     67.4%
# 2  $295,983,305  $680,553,613  2010.csv  2010      30.3%     69.7%
# 3  $292,576,195  $535,745,837  2010.csv  2010      35.3%     64.7%
# 4  $238,736,787  $513,864,080  2010.csv  2010      31.7%     68.3%

# %%
to_clean_cols = ['Worldwide', 'Domestic', 'Foreign']

def currency_str_to_int(current_val):
    current_val = current_val.replace('$', '').replace(',', '')
    try:
        current_val = int(current_val)
    except:
        # Take any row value with '-' and turns into 0
        current_val = 0
    return current_val

def clean_col(row):
#     print(row)
    for col in to_clean_cols:
        current_val = row[col]
        row[col] = currency_str_to_int(current_val)
    return row

df_cleaned = df.apply(clean_col, axis=1)
df_cleaned.head()
# Out:
#    Rank                                 Release Group   Worldwide   Domestic  \
# 0    -1                                   Toy Story 3  1066969703  415004880
# 1    -1                           Alice in Wonderland  1025467110  334191110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1   976536918  295983305
# 3    -1                                     Inception   828322032  292576195
# 4    -1                           Shrek Forever After   752600867  238736787
#
#      Foreign  filename  year Domestic % Foreign %
# 0  651964823  2010.csv  2010      38.9%     61.1%
# 1  691276000  2010.csv  2010      32.6%     67.4%
# 2  680553613  2010.csv  2010      30.3%     69.7%
# 3  535745837  2010.csv  2010      35.3%     64.7%
# 4  513864080  2010.csv  2010      31.7%     68.3%

# %%
df_cleaned.tail()
# Out:
#       Rank                          Release Group  Worldwide  Domestic  \
# 7393    -1                         The Fox Hunter       1577      1577
# 7394    -1                          Hai Tang Hong       1107      1107
# 7395    -1                      The Transcendents       1090      1090
# 7396    -1  Inception 10th Anniversary re-release        387         0
# 7397    -1                        Spaceship Earth        168         0
#
#       Foreign  filename  year Domestic % Foreign %
# 7393        0  2020.csv  2020       100%         -
# 7394        0  2020.csv  2020       100%         -
# 7395        0  2020.csv  2020       100%         -
# 7396      387  2020.csv  2020          -      100%
# 7397      168  2020.csv  2020          -      100%

# %%
df_cleaned.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Foreign           int64
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df_cleaned.sort_values(by=['Worldwide'], inplace=True, ascending=False)
df_cleaned.head()
# Out:
#       Rank                               Release Group   Worldwide   Domestic  \
# 6471    -1                           Avengers: Endgame  2797800564  858373000
# 3306    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 5583    -1                      Avengers: Infinity War  2048359754  678815482
# 3307    -1                              Jurassic World  1670400637  652270625
# 6472    -1                               The Lion King  1656943394  543638043
#
#          Foreign  filename  year Domestic % Foreign %
# 6471  1939427564  2019.csv  2019      30.7%     69.3%
# 3306  1131561399  2015.csv  2015      45.3%     54.7%
# 5583  1369544272  2018.csv  2018      33.1%     66.9%
# 3307  1018130012  2015.csv  2015        39%       61%
# 6472  1113305351  2019.csv  2019      32.8%     67.2%

# %%
df_cleaned.reset_index(inplace=True, drop=True)
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0    -1                           Avengers: Endgame  2797800564  858373000
# 1    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2    -1                      Avengers: Infinity War  2048359754  678815482
# 3    -1                              Jurassic World  1670400637  652270625
# 4    -1                               The Lion King  1656943394  543638043
#
#       Foreign  filename  year Domestic % Foreign %
# 0  1939427564  2019.csv  2019      30.7%     69.3%
# 1  1131561399  2015.csv  2015      45.3%     54.7%
# 2  1369544272  2018.csv  2018      33.1%     66.9%
# 3  1018130012  2015.csv  2015        39%       61%
# 4  1113305351  2019.csv  2019      32.8%     67.2%

# %%
df_cleaned['Rank'] = df_cleaned.index + 1
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign  filename  year Domestic % Foreign %
# 0  1939427564  2019.csv  2019      30.7%     69.3%
# 1  1131561399  2015.csv  2015      45.3%     54.7%
# 2  1369544272  2018.csv  2018      33.1%     66.9%
# 3  1018130012  2015.csv  2015        39%       61%
# 4  1113305351  2019.csv  2019      32.8%     67.2%

# %%
df_cleaned['Domestic %'] = df_cleaned['Domestic'] / df_cleaned['Worldwide']
df_cleaned['Foreign %'] = df_cleaned['Foreign'] / df_cleaned['Worldwide']

# %%
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign  filename  year  Domestic %  Foreign %
# 0  1939427564  2019.csv  2019    0.306803   0.693197
# 1  1131561399  2015.csv  2015    0.452882   0.547118
# 2  1369544272  2018.csv  2018    0.331395   0.668605
# 3  1018130012  2015.csv  2015    0.390488   0.609512
# 4  1113305351  2019.csv  2019    0.328097   0.671903

# %%
df_cleaned.dtypes
# Out:
# Rank               int64
# Release Group     object
# Worldwide          int64
# Domestic           int64
# Foreign            int64
# filename          object
# year               int64
# Domestic %       float64
# Foreign %        float64
# dtype: object

# %%
df_cleaned.to_csv(output_file, index=False)
